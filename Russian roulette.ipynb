# %%
import random
import time
from IPython.display import Audio

# %%
starter=random.randint(1,2)
chamber=random.randint(1,6)
for i in range(1,7):

        if starter==1:
           print('player 1 starts')
           player_1=input(' player_1 pull the trigger (press enter)')
           #display(Audio('/content/Dry-Pistol-Gunfire-Single-A-www.fesliyanstudios.com.mp3',autoplay=True))
           if chamber==1:
              display(Audio('/content/Smith-&-Wesson-500-Magnum-Close-Single-Gunshot-A-www.fesliyanstudios.com.mp3',autoplay=True))
              print('player 1 is dead')
              break
           else:
              display(Audio('/content/Dry-Pistol-Gunfire-Single-A-www.fesliyanstudios.com.mp3',autoplay=True))
              time.sleep(1)

              #ps.stop()
           chamber+=1
           if chamber==7:
              chamber=1
        else:
           print('player 2 starts')
           player_2=input(' player_2 pull the trigger (press enter)')
          # display(Audio('/content/Dry-Pistol-Gunfire-Single-A-www.fesliyanstudios.com.mp3',autoplay=True))
           if chamber==1:
              display(Audio('/content/Smith-&-Wesson-500-Magnum-Close-Single-Gunshot-A-www.fesliyanstudios.com.mp3',autoplay==True))
              print('player 2 is dead')
              break
           else:
              display(Audio('/content/Dry-Pistol-Gunfire-Single-A-www.fesliyanstudios.com.mp3',autoplay=True))
              time.sleep(1)

           chamber+=1
           if chamber==7:
              chamber=1
        if starter==1:
           starter=2

        elif starter==2:
           starter=1
# Out:
# player 1 starts
#  player_1 pull the trigger (press enter)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# player 2 starts
#  player_2 pull the trigger (press enter)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# player 1 starts
#  player_1 pull the trigger (press enter)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# player 2 starts
#  player_2 pull the trigger (press enter)
# ...
